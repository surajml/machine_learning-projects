# %%
import pandas as pd

# %%
# data = pd.read_csv('nba_final.csv')
data = pd.read_csv('nba_final.csv')

# %%
data.shape
# Out:
# (1408, 45)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1408 entries, 0 to 1407
# Data columns (total 45 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rk          1408 non-null   int64
#  1   Player.x    1408 non-null   object
#  2   Player_ID   1408 non-null   object
#  3   Pos1        1408 non-null   object
#  4   Pos2        12 non-null     object
#  5   Age         1408 non-null   int64
#  6   Tm          1408 non-null   object
#  7   G           1408 non-null   int64
#  8   GS          1408 non-null   int64
#  9   MP          1408 non-null   float64
#  10  FG          1408 non-null   float64
#  11  FGA         1408 non-null   float64
#  12  FG.         1404 non-null   float64
#  13  X3P         1408 non-null   float64
#  14  X3PA        1408 non-null   float64
#  15  X3P.        1309 non-null   float64
#  16  X2P         1408 non-null   float64
#  17  X2PA        1408 non-null   float64
#  18  X2P.        1393 non-null   float64
#  19  eFG.        1404 non-null   float64
#  20  FT          1408 non-null   float64
#  21  FTA         1408 non-null   float64
#  22  FT.         1361 non-null   float64
#  23  ORB         1408 non-null   float64
#  24  DRB         1408 non-null   float64
#  25  TRB         1408 non-null   float64
#  26  AST         1408 non-null   float64
#  27  STL         1408 non-null   float64
#  28  BLK         1408 non-null   float64
#  29  TOV         1408 non-null   float64
#  30  PF          1408 non-null   float64
#  31  PTS         1408 non-null   float64
#  32  Salary      1346 non-null   float64
#  33  mean_views  1270 non-null   float64
#  34  Season      1408 non-null   object
#  35  Conference  1408 non-null   object
#  36  Role        1408 non-null   object
#  37  Fvot        1408 non-null   int64
#  38  FRank       1408 non-null   int64
#  39  Pvot        1249 non-null   float64
#  40  PRank       1249 non-null   float64
#  41  Mvot        1004 non-null   float64
#  42  MRank       1004 non-null   float64
#  43  Score       1408 non-null   float64
#  44  Play        1408 non-null   object
# dtypes: float64(30), int64(6), object(9)
# memory usage: 495.1+ KB

# %%
data.describe().T
# Out:
#              count          mean           std           min           25%  \
# Rk          1408.0  2.577017e+02  1.507659e+02      1.000000  1.270000e+02
# Age         1408.0  2.613920e+01  4.282550e+00     19.000000  2.300000e+01
# G           1408.0  5.409943e+01  2.405251e+01      1.000000  3.600000e+01
# GS          1408.0  2.590696e+01  2.866458e+01      0.000000  1.000000e+00
# MP          1408.0  2.016271e+01  9.066041e+00      0.700000  1.330000e+01
# FG          1408.0  3.262429e+00  2.181694e+00      0.000000  1.600000e+00
# FGA         1408.0  7.173153e+00  4.591826e+00      0.000000  3.700000e+00
# FG.         1404.0  4.476033e-01  9.176138e-02      0.000000  4.040000e-01
# X3P         1408.0  8.562500e-01  7.923071e-01      0.000000  2.000000e-01
# X3PA        1408.0  2.420810e+00  2.061737e+00      0.000000  7.000000e-01
# X3P.        1309.0  3.125095e-01  1.271640e-01      0.000000  2.860000e-01
# X2P         1408.0  2.406321e+00  1.812374e+00      0.000000  1.000000e+00
# X2PA        1408.0  4.752770e+00  3.427045e+00      0.000000  2.100000e+00
# X2P.        1393.0  4.966992e-01  9.391328e-02      0.000000  4.540000e-01
# eFG.        1404.0  5.053875e-01  9.478157e-02      0.000000  4.730000e-01
# FT          1408.0  1.417401e+00  1.369218e+00      0.000000  5.000000e-01
# FTA         1408.0  1.855327e+00  1.678879e+00      0.000000  7.000000e-01
# FT.         1361.0  7.408339e-01  1.295715e-01      0.000000  6.780000e-01
# ORB         1408.0  8.475142e-01  7.697050e-01      0.000000  3.000000e-01
# DRB         1408.0  2.824645e+00  1.853155e+00      0.000000  1.500000e+00
# TRB         1408.0  3.670170e+00  2.482460e+00      0.000000  1.900000e+00
# AST         1408.0  1.935227e+00  1.791822e+00      0.000000  7.000000e-01
# STL         1408.0  6.407670e-01  4.160258e-01      0.000000  3.000000e-01
# BLK         1408.0  4.026989e-01  4.036875e-01      0.000000  1.000000e-01
# TOV         1408.0  1.130540e+00  8.032480e-01      0.000000  6.000000e-01
# PF          1408.0  1.726065e+00  7.517208e-01      0.000000  1.200000e+00
# PTS         1408.0  8.794176e+00  6.081955e+00      0.000000  4.300000e+00
# Salary      1346.0  6.790048e+06  7.452558e+06  56845.000000  1.471382e+06
# mean_views  1270.0  9.888023e+02  2.131279e+03      1.142857  2.035733e+02
# Fvot        1408.0  1.176963e+05  4.286272e+05      3.000000  2.135500e+03
# FRank       1408.0  6.159517e+01  3.668110e+01      1.000000  3.000000e+01
# Pvot        1249.0  8.135308e+00  2.642785e+01      0.000000  0.000000e+00
# PRank       1249.0  4.327222e+01  2.346915e+01      1.000000  2.400000e+01
# Mvot        1004.0  2.938247e+00  1.484940e+01      0.000000  0.000000e+00
# MRank       1004.0  7.149402e+00  1.498284e+00      1.000000  6.000000e+00
# Score       1408.0  7.557834e+01  4.140498e+01      1.000000  4.500000e+01
#
#                      50%           75%           max
# Rk          2.570000e+02  3.852500e+02  5.400000e+02
# Age         2.500000e+01  2.900000e+01  4.200000e+01
# G           6.200000e+01  7.400000e+01  8.200000e+01
# GS          1.300000e+01  5.200000e+01  8.200000e+01
# MP          2.000000e+01  2.750000e+01  3.780000e+01
# FG          2.800000e+00  4.500000e+00  1.080000e+01
# FGA         6.150000e+00  9.900000e+00  2.450000e+01
# FG.         4.440000e-01  4.900000e-01  1.000000e+00
# X3P         7.000000e-01  1.300000e+00  5.100000e+00
# X3PA        2.050000e+00  3.700000e+00  1.320000e+01
# X3P.        3.400000e-01  3.750000e-01  1.000000e+00
# X2P         1.900000e+00  3.300000e+00  9.700000e+00
# X2PA        3.800000e+00  6.700000e+00  1.920000e+01
# X2P.        4.980000e-01  5.450000e-01  1.000000e+00
# eFG.        5.100000e-01  5.490000e-01  1.500000e+00
# FT          1.000000e+00  1.900000e+00  9.700000e+00
# FTA         1.300000e+00  2.500000e+00  1.100000e+01
# FT.         7.650000e-01  8.270000e-01  1.000000e+00
# ORB         6.000000e-01  1.100000e+00  5.400000e+00
# DRB         2.400000e+00  3.700000e+00  1.110000e+01
# TRB         3.100000e+00  4.700000e+00  1.600000e+01
# AST         1.300000e+00  2.500000e+00  1.120000e+01
# STL         6.000000e-01  9.000000e-01  2.400000e+00
# BLK         3.000000e-01  5.000000e-01  2.700000e+00
# TOV         9.000000e-01  1.500000e+00  5.700000e+00
# PF          1.700000e+00  2.200000e+00  4.000000e+00
# PTS         7.300000e+00  1.200000e+01  3.610000e+01
# Salary      3.384298e+06  1.043234e+07  3.745715e+07
# mean_views  4.109219e+02  9.301634e+02  3.414796e+04
# Fvot        6.843000e+03  2.925250e+04  4.620809e+06
# FRank       6.000000e+01  9.025000e+01  1.450000e+02
# Pvot        1.000000e+00  4.000000e+00  2.690000e+02
# PRank       4.300000e+01  6.000000e+01  8.800000e+01
# Mvot        0.000000e+00  0.000000e+00  1.000000e+02
# MRank       7.000000e+00  8.000000e+00  9.000000e+00
# Score       6.990000e+01  1.092000e+02  1.668000e+02

# %%
data.isna().sum()
# Out:
# Rk               0
# Player.x         0
# Player_ID        0
# Pos1             0
# Pos2          1396
# Age              0
# Tm               0
# G                0
# GS               0
# MP               0
# FG               0
# FGA              0
# FG.              4
# X3P              0
# X3PA             0
# X3P.            99
# X2P              0
# X2PA             0
# X2P.            15
# eFG.             4
# FT               0
# FTA              0
# FT.             47
# ORB              0
# DRB              0
# TRB              0
# AST              0
# STL              0
# BLK              0
# TOV              0
# PF               0
# PTS              0
# Salary          62
# mean_views     138
# Season           0
# Conference       0
# Role             0
# Fvot             0
# FRank            0
# Pvot           159
# PRank          159
# Mvot           404
# MRank          404
# Score            0
# Play             0
# dtype: int64

# %%
data.head().T
# Out:
#                        0             1             2              3  \
# Rk                   170            58           157            352
# Player.x    A.J. Hammons  Aaron Brooks  Aaron Gordon  Adreian Payne
# Player_ID      hammoaj01     brookaa01     gordoaa01      paynead01
# Pos1                   C            PG            SF             PF
# Pos2                 NaN           NaN           NaN            NaN
# Age                   24            32            21             25
# Tm                   DAL           IND           ORL            MIN
# G                     22            65            80             18
# GS                     0             0            72              0
# MP                   7.4          13.8          28.7            7.5
# FG                   0.8           1.9           4.9            1.3
# FGA                  1.9           4.6          10.8            3.0
# FG.                0.405         0.403         0.454          0.426
# X3P                  0.2           0.7           1.0            0.2
# X3PA                 0.5           2.0           3.3            0.8
# X3P.                 0.5         0.375         0.288            0.2
# X2P                  0.5           1.1           4.0            1.1
# X2PA                 1.5           2.6           7.5            2.2
# X2P.               0.375         0.424         0.528          0.513
# eFG.               0.464         0.483         0.499          0.454
# FT                   0.4           0.5           2.0            0.8
# FTA                  0.9           0.6           2.7            1.1
# FT.                 0.45           0.8         0.719          0.737
# ORB                  0.4           0.3           1.5            0.5
# DRB                  1.3           0.8           3.6            1.3
# TRB                  1.6           1.1           5.1            1.8
# AST                  0.2           1.9           1.9            0.4
# STL                  0.0           0.4           0.8            0.4
# BLK                  0.6           0.1           0.5            0.4
# TOV                  0.5           1.0           1.1            0.4
# PF                   1.0           1.4           2.2            1.8
# PTS                  2.2           5.0          12.7            3.5
# Salary               NaN     2700000.0     4351320.0      2022240.0
# mean_views          3.32     11.155738   1713.986339     205.855191
# Season           2016-17       2016-17       2016-17        2016-17
# Conference          West           Est           Est           West
# Role               Front          Back         Front          Front
# Fvot                 786          2474         22774            861
# FRank                123            64            29            120
# Pvot                 NaN           NaN           NaN            1.0
# PRank                NaN           NaN           NaN           52.0
# Mvot                 NaN           NaN           NaN            NaN
# MRank                NaN           NaN           NaN            NaN
# Score               83.5          48.2          40.0           75.5
# Play                  No            No            No             No
#
#                           4
# Rk                       10
# Player.x    Al-Farouq Aminu
# Player_ID         aminual01
# Pos1                     PF
# Pos2                    NaN
# Age                      26
# Tm                      POR
# G                        61
# GS                       25
# MP                     29.1
# FG                      3.0
# FGA                     7.6
# FG.                   0.393
# X3P                     1.1
# X3PA                    3.5
# X3P.                   0.33
# X2P                     1.9
# X2PA                    4.2
# X2P.                  0.445
# eFG.                  0.468
# FT                      1.6
# FTA                     2.2
# FT.                   0.706
# ORB                     1.3
# DRB                     6.1
# TRB                     7.4
# AST                     1.6
# STL                     1.0
# BLK                     0.7
# TOV                     1.5
# PF                      1.7
# PTS                     8.7
# Salary            7680965.0
# mean_views        604.34153
# Season              2016-17
# Conference             West
# Role                  Front
# Fvot                   4971
# FRank                    69
# Pvot                    7.0
# PRank                  23.0
# Mvot                    NaN
# MRank                   NaN
# Score                  42.8
# Play                     No

# %%
import numpy as np
data['Pos2'] = data['Pos2'].replace(np.nan, 'NONE')
data['Pos2'].unique()
# Out:
# array(['NONE', 'C', 'SG', 'SF', 'PF'], dtype=object)

# %%
data = data.fillna(0)

# %%
data.isna().sum()
# Out:
# Rk            0
# Player.x      0
# Player_ID     0
# Pos1          0
# Pos2          0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG.           0
# X3P           0
# X3PA          0
# X3P.          0
# X2P           0
# X2PA          0
# X2P.          0
# eFG.          0
# FT            0
# FTA           0
# FT.           0
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# Salary        0
# mean_views    0
# Season        0
# Conference    0
# Role          0
# Fvot          0
# FRank         0
# Pvot          0
# PRank         0
# Mvot          0
# MRank         0
# Score         0
# Play          0
# dtype: int64

# %%
data.head().T
# Out:
#                        0             1             2              3  \
# Rk                   170            58           157            352
# Player.x    A.J. Hammons  Aaron Brooks  Aaron Gordon  Adreian Payne
# Player_ID      hammoaj01     brookaa01     gordoaa01      paynead01
# Pos1                   C            PG            SF             PF
# Pos2                NONE          NONE          NONE           NONE
# Age                   24            32            21             25
# Tm                   DAL           IND           ORL            MIN
# G                     22            65            80             18
# GS                     0             0            72              0
# MP                   7.4          13.8          28.7            7.5
# FG                   0.8           1.9           4.9            1.3
# FGA                  1.9           4.6          10.8            3.0
# FG.                0.405         0.403         0.454          0.426
# X3P                  0.2           0.7           1.0            0.2
# X3PA                 0.5           2.0           3.3            0.8
# X3P.                 0.5         0.375         0.288            0.2
# X2P                  0.5           1.1           4.0            1.1
# X2PA                 1.5           2.6           7.5            2.2
# X2P.               0.375         0.424         0.528          0.513
# eFG.               0.464         0.483         0.499          0.454
# FT                   0.4           0.5           2.0            0.8
# FTA                  0.9           0.6           2.7            1.1
# FT.                 0.45           0.8         0.719          0.737
# ORB                  0.4           0.3           1.5            0.5
# DRB                  1.3           0.8           3.6            1.3
# TRB                  1.6           1.1           5.1            1.8
# AST                  0.2           1.9           1.9            0.4
# STL                  0.0           0.4           0.8            0.4
# BLK                  0.6           0.1           0.5            0.4
# TOV                  0.5           1.0           1.1            0.4
# PF                   1.0           1.4           2.2            1.8
# PTS                  2.2           5.0          12.7            3.5
# Salary               0.0     2700000.0     4351320.0      2022240.0
# mean_views          3.32     11.155738   1713.986339     205.855191
# Season           2016-17       2016-17       2016-17        2016-17
# Conference          West           Est           Est           West
# Role               Front          Back         Front          Front
# Fvot                 786          2474         22774            861
# FRank                123            64            29            120
# Pvot                 0.0           0.0           0.0            1.0
# PRank                0.0           0.0           0.0           52.0
# Mvot                 0.0           0.0           0.0            0.0
# MRank                0.0           0.0           0.0            0.0
# Score               83.5          48.2          40.0           75.5
# Play                  No            No            No             No
#
#                           4
# Rk                       10
# Player.x    Al-Farouq Aminu
# Player_ID         aminual01
# Pos1                     PF
# Pos2                   NONE
# Age                      26
# Tm                      POR
# G                        61
# GS                       25
# MP                     29.1
# FG                      3.0
# FGA                     7.6
# FG.                   0.393
# X3P                     1.1
# X3PA                    3.5
# X3P.                   0.33
# X2P                     1.9
# X2PA                    4.2
# X2P.                  0.445
# eFG.                  0.468
# FT                      1.6
# FTA                     2.2
# FT.                   0.706
# ORB                     1.3
# DRB                     6.1
# TRB                     7.4
# AST                     1.6
# STL                     1.0
# BLK                     0.7
# TOV                     1.5
# PF                      1.7
# PTS                     8.7
# Salary            7680965.0
# mean_views        604.34153
# Season              2016-17
# Conference             West
# Role                  Front
# Fvot                   4971
# FRank                    69
# Pvot                    7.0
# PRank                  23.0
# Mvot                    0.0
# MRank                   0.0
# Score                  42.8
# Play                     No

# %%
data = data.drop(['Player.x','Player_ID'], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder 

Le = LabelEncoder()

data['Pos1'] = Le.fit_transform(data['Pos1'])
data['Pos2'] = Le.fit_transform(data['Pos2'])
data['Tm'] = Le.fit_transform(data['Tm'])
data['Season'] = Le.fit_transform(data['Season'])
data['Conference'] = Le.fit_transform(data['Conference'])
data['Role'] = Le.fit_transform(data['Role'])
data['Play'] = Le.fit_transform(data['Play'])

# %%
data.head().T
# Out:
#                   0             1             2             3             4
# Rk          170.000  5.800000e+01  1.570000e+02  3.520000e+02  1.000000e+01
# Pos1          0.000  2.000000e+00  3.000000e+00  1.000000e+00  1.000000e+00
# Pos2          1.000  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# Age          24.000  3.200000e+01  2.100000e+01  2.500000e+01  2.600000e+01
# Tm            6.000  1.100000e+01  2.100000e+01  1.700000e+01  2.400000e+01
# G            22.000  6.500000e+01  8.000000e+01  1.800000e+01  6.100000e+01
# GS            0.000  0.000000e+00  7.200000e+01  0.000000e+00  2.500000e+01
# MP            7.400  1.380000e+01  2.870000e+01  7.500000e+00  2.910000e+01
# FG            0.800  1.900000e+00  4.900000e+00  1.300000e+00  3.000000e+00
# FGA           1.900  4.600000e+00  1.080000e+01  3.000000e+00  7.600000e+00
# FG.           0.405  4.030000e-01  4.540000e-01  4.260000e-01  3.930000e-01
# X3P           0.200  7.000000e-01  1.000000e+00  2.000000e-01  1.100000e+00
# X3PA          0.500  2.000000e+00  3.300000e+00  8.000000e-01  3.500000e+00
# X3P.          0.500  3.750000e-01  2.880000e-01  2.000000e-01  3.300000e-01
# X2P           0.500  1.100000e+00  4.000000e+00  1.100000e+00  1.900000e+00
# X2PA          1.500  2.600000e+00  7.500000e+00  2.200000e+00  4.200000e+00
# X2P.          0.375  4.240000e-01  5.280000e-01  5.130000e-01  4.450000e-01
# eFG.          0.464  4.830000e-01  4.990000e-01  4.540000e-01  4.680000e-01
# FT            0.400  5.000000e-01  2.000000e+00  8.000000e-01  1.600000e+00
# FTA           0.900  6.000000e-01  2.700000e+00  1.100000e+00  2.200000e+00
# FT.           0.450  8.000000e-01  7.190000e-01  7.370000e-01  7.060000e-01
# ORB           0.400  3.000000e-01  1.500000e+00  5.000000e-01  1.300000e+00
# DRB           1.300  8.000000e-01  3.600000e+00  1.300000e+00  6.100000e+00
# TRB           1.600  1.100000e+00  5.100000e+00  1.800000e+00  7.400000e+00
# AST           0.200  1.900000e+00  1.900000e+00  4.000000e-01  1.600000e+00
# STL           0.000  4.000000e-01  8.000000e-01  4.000000e-01  1.000000e+00
# BLK           0.600  1.000000e-01  5.000000e-01  4.000000e-01  7.000000e-01
# TOV           0.500  1.000000e+00  1.100000e+00  4.000000e-01  1.500000e+00
# PF            1.000  1.400000e+00  2.200000e+00  1.800000e+00  1.700000e+00
# PTS           2.200  5.000000e+00  1.270000e+01  3.500000e+00  8.700000e+00
# Salary        0.000  2.700000e+06  4.351320e+06  2.022240e+06  7.680965e+06
# mean_views    3.320  1.115574e+01  1.713986e+03  2.058552e+02  6.043415e+02
# Season        0.000  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Conference    1.000  0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# Role          1.000  0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# Fvot        786.000  2.474000e+03  2.277400e+04  8.610000e+02  4.971000e+03
# FRank       123.000  6.400000e+01  2.900000e+01  1.200000e+02  6.900000e+01
# Pvot          0.000  0.000000e+00  0.000000e+00  1.000000e+00  7.000000e+00
# PRank         0.000  0.000000e+00  0.000000e+00  5.200000e+01  2.300000e+01
# Mvot          0.000  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# MRank         0.000  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Score        83.500  4.820000e+01  4.000000e+01  7.550000e+01  4.280000e+01
# Play          0.000  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00

# %%
X = data.drop(['Play'], axis=1)
y = data['Play']

# %%
#standardize
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X = sc.fit_transform(X)

# %%
X.shape
# Out:
# (1408, 42)

# %%
#LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=1)
X = lda.fit_transform(X, y)

# %%
X.shape
# Out:
# (1408, 1)

# %%
X
# Out:
# array([[-1.03229414],
#        [-0.50134906],
#        [-0.57346384],
#        ...,
#        [-0.72836767],
#        [-0.37294989],
#        [-0.8653202 ]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state=29)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
lr_pred = lr.predict(X_test)

# %%
from sklearn.metrics import classification_report

cr = classification_report(lr_pred, y_test)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       409
#            1       0.68      0.93      0.79        14
#
#     accuracy                           0.98       423
#    macro avg       0.84      0.96      0.89       423
# weighted avg       0.99      0.98      0.98       423

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = dt.predict(X_test)

# %%
cr_dt = classification_report(pred_dt, y_test)
print(cr_dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       401
#            1       0.68      0.59      0.63        22
#
#     accuracy                           0.96       423
#    macro avg       0.83      0.79      0.81       423
# weighted avg       0.96      0.96      0.96       423

# %%
#random forest classifier
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
pred_rf = rf.predict(X_train)

# %%
cr_rf = classification_report(pred_rf, y_train)
print(cr_rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       931
#            1       1.00      1.00      1.00        54
#
#     accuracy                           1.00       985
#    macro avg       1.00      1.00      1.00       985
# weighted avg       1.00      1.00      1.00       985

# %%
pred_rf = rf.predict(X_test)

# %%
cr_rf = classification_report(pred_rf, y_test)
print(cr_rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       401
#            1       0.68      0.59      0.63        22
#
#     accuracy                           0.96       423
#    macro avg       0.83      0.79      0.81       423
# weighted avg       0.96      0.96      0.96       423
